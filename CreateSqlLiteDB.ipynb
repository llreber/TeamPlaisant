# %%
# Dependencies and Setup
import pandas as pd
import numpy as np

# %%
# File to Load
aid_data_to_load = "us_foreign_aid_modified.csv"

# Read Data File and store into Pandas Data Frames
aid_data = pd.read_csv(aid_data_to_load)
aid_data.head()
# Out:
#   country_code country_name  latitude  longitude             region_name  \
# 0          AFG  Afghanistan  33.93911  67.709953  South and Central Asia
# 1          AFG  Afghanistan  33.93911  67.709953  South and Central Asia
# 2          AFG  Afghanistan  33.93911  67.709953  South and Central Asia
# 3          AFG  Afghanistan  33.93911  67.709953  South and Central Asia
# 4          AFG  Afghanistan  33.93911  67.709953  South and Central Asia
#
#     income_group_name income_group_acronym implementing_agency_acronym  \
# 0  Low Income Country                  LIC                         DOD
# 1  Low Income Country                  LIC                         DOD
# 2  Low Income Country                  LIC                         DOD
# 3  Low Income Country                  LIC                         DOD
# 4  Low Income Country                  LIC                         DOD
#
#   implementing_agency_name subagency_acronym      ...       \
# ...

# %%
from sqlalchemy import create_engine
engine = create_engine('sqlite:///aid_data.sqlite', echo=False)

# %%
aid_data.to_sql("aid_data", con=engine, if_exists = "replace", chunksize = 10)

# %%
engine.execute("SELECT * FROM aid_data WHERE fiscal_year = 2016").fetchall()
# Out:
# [(22, 'AFG', 'Afghanistan', 33.93911, 67.709953, 'South and Central Asia', 'Low Income Country', 'LIC', 'DOD', 'Department of Defense', None, 'not applicable', 'Government', 'Government - United States', 'U.S. Government - Department of Defense', 'Governance', 'Conflict, Peace, and Security', 'Security system management and reform', '21x2091', 'Department of the Army, Afghanistan Security Forces Fund', 'Department of the Army', 'ARMY', 'Military', 'Project-Type', 'Afghanistan Security Force Fund', None, None, None, 2, 'Obligations', 2016, 3754000000, 3754000000, 'Stabilization Operations and Security Sector Reform', 28),
# ...
